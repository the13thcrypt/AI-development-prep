# %%
import nltk
from nltk import tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text="this a an eXample to demonstrate The Use of stop words in nlp. this is another sentence"
text.lower()
# Out:
# 'this a an example to demonstrate the use of stop words in nlp. this is another sentence'

# %%
import nltk
nltk.download('punkt_tab')

words = word_tokenize(text.lower())
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Get English stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Filter out stopwords
filtered_words = [word for word in words if word.lower() not in stop_words]

print("Original words:", words)
print("Filtered words (without stopwords):", filtered_words)
# Out:
# Original words: ['this', 'a', 'an', 'example', 'to', 'demonstrate', 'the', 'use', 'of', 'stop', 'words', 'in', 'nlp', '.', 'this', 'is', 'another', 'sentence']
# Filtered words (without stopwords): ['example', 'demonstrate', 'use', 'stop', 'words', 'nlp', '.', 'another', 'sentence']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
